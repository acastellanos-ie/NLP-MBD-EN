# %% [markdown]
# <a href="https://colab.research.google.com/github/acastellanos-ie/NLP-MBD-EN/blob/main/basic_text_processing/tokenization_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Instalar librerías necesarias
# !pip install streamlit tiktoken plotly -q

# 2. Escribir el código de la app en un archivo app.py
# %%writefile app.py
import streamlit as st
import tiktoken
import plotly.graph_objects as go

# --- PEGA AQUÍ EL CÓDIGO DE LA APP QUE TE DI ANTES ---
# (Copia todo el bloque de código de mi respuesta anterior y pégalo justo aquí,
# respetando la indentación debajo de %%writefile)
